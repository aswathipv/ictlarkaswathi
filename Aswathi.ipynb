# %% [markdown]
# # Read dataset

# %%
import pandas as pd

# %%
data=pd.read_excel('iris.xls')

# %% [markdown]
# # Display columns

# %%
data.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %% [markdown]
# # Mean of each columns in dataset

# %%
data.mean(axis=0)
# Out:
# C:\Users\vivek\AppData\Local\Temp/ipykernel_11436/2773904261.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.mean(axis=0)
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %% [markdown]
# # Null values in dataset

# %%
data.isnull()
# Out:
#         SL     SW     PL     PW  Classification
# 0    False  False  False  False           False
# 1    False  False  False  False           False
# 2    False  False  False  False           False
# 3    False  False  False  False           False
# 4    False  False  False  False           False
# ..     ...    ...    ...    ...             ...
# 145  False  False  False  False           False
# 146  False  False  False  False           False
# 147  False  False  False  False           False
# 148  False  False  False  False           False
# 149  False  False  False  False           False
#
# [150 rows x 5 columns]

# %%
data.isnull().values.any()
# Out:
# False

# %% [markdown]
# # visualizations

# %%
import matplotlib.pyplot as plt

# %%
plt.figure()
plt.plot(data['SL'],data['Classification'])

# %%
plt.plot(data['SW'],data['Classification'])

# %%
plt.plot(data['PL'],data['Classification'])

# %%
plt.plot(data['PW'],data['Classification'])

# %%
import seaborn as sns

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   SL              150 non-null    float64
#  1   SW              150 non-null    float64
#  2   PL              150 non-null    float64
#  3   PW              150 non-null    float64
#  4   Classification  150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
plt.scatter(data[data['Classification']=='Iris-setosa']['SW'],data[data['Classification']=='Iris-setosa']['SL'])
plt.scatter(data[data['Classification']=='Iris-versicolor']['SW'],data[data['Classification']=='Iris-versicolor']['SL'])
plt.scatter(data[data['Classification']=='Iris-virginica']['SW'],data[data['Classification']=='Iris-virginica']['SL'])
plt.title("Scatter plot of Sepal width and Sepal length",fontsize=10)
plt.xlabel("Sepel Width",fontsize=10)
plt.ylabel("Sepel length",fontsize=10)
# Out:
# Text(0, 0.5, 'Sepel length')

# %%
sns.pairplot(data)

# %%
plt.scatter(data[data['Classification']=='Iris-setosa']['PW'],data[data['Classification']=='Iris-setosa']['PL'])
plt.scatter(data[data['Classification']=='Iris-versicolor']['PW'],data[data['Classification']=='Iris-versicolor']['PL'])
plt.scatter(data[data['Classification']=='Iris-virginica']['PW'],data[data['Classification']=='Iris-virginica']['PL'])
plt.title("Scatter plot of petal width and petal length",fontsize=10)
plt.xlabel("petal Width",fontsize=10)
plt.ylabel("petal length",fontsize=10)
# Out:
# Text(0, 0.5, 'petal length')
