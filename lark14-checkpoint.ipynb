# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('Country-data.csv')

# %%
data.head()
# Out:
#                country  child_mort  exports  health  imports  income  \
# 0          Afghanistan        90.2     10.0    7.58     44.9    1610
# 1              Albania        16.6     28.0    6.55     48.6    9930
# 2              Algeria        27.3     38.4    4.17     31.4   12900
# 3               Angola       119.0     62.3    2.85     42.9    5900
# 4  Antigua and Barbuda        10.3     45.5    6.03     58.9   19100
#
#    inflation  life_expec  total_fer   gdpp
# 0       9.44        56.2       5.82    553
# 1       4.49        76.3       1.65   4090
# 2      16.10        76.5       2.89   4460
# 3      22.40        60.1       6.16   3530
# 4       1.44        76.8       2.13  12200

# %%
data.describe()
# Out:
#        child_mort     exports      health     imports         income  \
# count  167.000000  167.000000  167.000000  167.000000     167.000000
# mean    38.270060   41.108976    6.815689   46.890215   17144.688623
# std     40.328931   27.412010    2.746837   24.209589   19278.067698
# min      2.600000    0.109000    1.810000    0.065900     609.000000
# 25%      8.250000   23.800000    4.920000   30.200000    3355.000000
# 50%     19.300000   35.000000    6.320000   43.300000    9960.000000
# 75%     62.100000   51.350000    8.600000   58.750000   22800.000000
# max    208.000000  200.000000   17.900000  174.000000  125000.000000
#
#         inflation  life_expec   total_fer           gdpp
# count  167.000000  167.000000  167.000000     167.000000
# mean     7.781832   70.555689    2.947964   12964.155689
# std     10.570704    8.893172    1.513848   18328.704809
# min     -4.210000   32.100000    1.150000     231.000000
# 25%      1.810000   65.300000    1.795000    1330.000000
# 50%      5.390000   73.100000    2.410000    4660.000000
# 75%     10.750000   76.800000    3.880000   14050.000000
# max    104.000000   82.800000    7.490000  105000.000000

# %%
data.isna().sum()
# Out:
# country       0
# child_mort    0
# exports       0
# health        0
# imports       0
# income        0
# inflation     0
# life_expec    0
# total_fer     0
# gdpp          0
# dtype: int64

# %%
data.shape
# Out:
# (167, 10)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize = (15,10))        
sns.heatmap(data.corr(),annot = True)
plt.show()

# %%
plt.figure(figsize = (20,14))
feature = data.columns[1:]
for i in enumerate(feature):
    plt.subplot(3,3, i[0]+1)
    sns.boxplot(data[i[1]],palette='winter')
# Out:
# C:\Users\vivek\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\vivek\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\vivek\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\vivek\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\vivek\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\vivek\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\vivek\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\vivek\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\vivek\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df=data

# %%
q2 = df['imports'].quantile(0.99)
q3 = df['health'].quantile(0.99)
q4 = df['income'].quantile(0.99)
q5 = df['inflation'].quantile(0.99)
q6 = df['life_expec'].quantile(0.99)
q7 = df['total_fer'].quantile(0.99)
q8 = df['gdpp'].quantile(0.99)

df['imports'][df['imports']>= q2] = q2
df['health'][df['health']>= q3] = q3
df['income'][df['income']>= q4] = q4
df['inflation'][df['inflation']>= q5] = q5
df['life_expec'][df['life_expec']>= q6] = q6
df['total_fer'][df['total_fer']>= q7] = q7
df['gdpp'][df['gdpp']>= q8] = q8
# Out:
# C:\Users\vivek\AppData\Local\Temp/ipykernel_9064/3938583779.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['imports'][df['imports']>= q2] = q2
# C:\Users\vivek\AppData\Local\Temp/ipykernel_9064/3938583779.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['health'][df['health']>= q3] = q3
# C:\Users\vivek\AppData\Local\Temp/ipykernel_9064/3938583779.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['income'][df['income']>= q4] = q4
# C:\Users\vivek\AppData\Local\Temp/ipykernel_9064/3938583779.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['inflation'][df['inflation']>= q5] = q5
# C:\Users\vivek\AppData\Local\Temp/ipykernel_9064/3938583779.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['life_expec'][df['life_expec']>= q6] = q6
# C:\Users\vivek\AppData\Local\Temp/ipykernel_9064/3938583779.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['total_fer'][df['total_fer']>= q7] = q7
# C:\Users\vivek\AppData\Local\Temp/ipykernel_9064/3938583779.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['gdpp'][df['gdpp']>= q8] = q8

# %%
df.describe()
# Out:
#        child_mort     exports      health     imports        income  \
# count  167.000000  167.000000  167.000000  167.000000    167.000000
# mean    38.270060   41.108976    6.780877   46.632390  16817.578137
# std     40.328931   27.412010    2.637739   23.014455  17808.895848
# min      2.600000    0.109000    1.810000    0.065900    609.000000
# 25%      8.250000   23.800000    4.920000   30.200000   3355.000000
# 50%     19.300000   35.000000    6.320000   43.300000   9960.000000
# 75%     62.100000   51.350000    8.600000   58.750000  22800.000000
# max    208.000000  200.000000   13.143234  142.471648  81036.274400
#
#         inflation  life_expec   total_fer          gdpp
# count  167.000000  167.000000  167.000000    167.000000
# mean     7.356842   70.549337    2.942115  12709.291171
# std      7.689433    8.884593    1.497990  17252.698522
# min     -4.210000   32.100000    1.150000    231.000000
# 25%      1.810000   65.300000    1.795000   1330.000000
# 50%      5.390000   73.100000    2.410000   4660.000000
# 75%     10.750000   76.800000    3.880000  14050.000000
# max     39.463337   82.219652    6.551572  75118.812800

# %%
from sklearn.preprocessing import MinMaxScaler
scalar = MinMaxScaler()
scaled_data = scalar.fit_transform(df)
scaled_data = pd.DataFrame(scaled_data, columns = df.columns)
scaled_data.describe()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9064/749342554.py in <module>
#       1 from sklearn.preprocessing import MinMaxScaler
#       2 scalar = MinMaxScaler()
# ----> 3 scaled_data = scalar.fit_transform(df)
#       4 scaled_data = pd.DataFrame(scaled_data, columns = df.columns)
#       5 scaled_data.describe()
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     697         if y is None:
#     698             # fit method of arity 1 (unsupervised transformation)
# --> 699             return self.fit(X, **fit_params).transform(X)
#     700         else:
#     701             # fit method of arity 2 (supervised transformation)
#
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in fit(self, X, y)
#     361         # Reset internal state before fitting
#     362         self._reset()
# --> 363         return self.partial_fit(X, y)
#     364
#     365     def partial_fit(self, X, y=None):
#
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in partial_fit(self, X, y)
#     394
#     395         first_pass = not hasattr(self, 'n_samples_seen_')
# --> 396         X = self._validate_data(X, reset=first_pass,
#     397                                 estimator=self, dtype=FLOAT_DTYPES,
#     398                                 force_all_finite="allow-nan")
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     419             out = X
#     420         elif isinstance(y, str) and y == 'no_validation':
# --> 421             X = check_array(X, **check_params)
#     422             out = X
#     423         else:
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     671                     array = array.astype(dtype, casting="unsafe", copy=False)
#     672                 else:
# --> 673                     array = np.asarray(array, order=order, dtype=dtype)
#     674             except ComplexWarning as complex_warning:
#     675                 raise ValueError("Complex data not supported\n"
#
# ~\anaconda3\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order, like)
#     100         return _asarray_with_like(a, dtype=dtype, order=order, like=like)
#     101
# --> 102     return array(a, dtype, copy=False, order=order)
#     103
#     104
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __array__(self, dtype)
#    1991
#    1992     def __array__(self, dtype: NpDtype | None = None) -> np.ndarray:
# -> 1993         return np.asarray(self._values, dtype=dtype)
#    1994
#    1995     def __array_wrap__(
#
# ~\anaconda3\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order, like)
#     100         return _asarray_with_like(a, dtype=dtype, order=order, like=like)
#     101
# --> 102     return array(a, dtype, copy=False, order=order)
#     103
#     104
#
# ValueError: could not convert string to float: 'Afghanistan'

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components = 2)
pca.fit(scaled_data)
x_pca = pca.transform(scaled_data)
x_pca.shape
# Out:
# (167, 2)

# %%
df1=df.drop('country',axis=1)

# %%
import scipy.cluster.hierarchy as sch
dendogram=sch.dendrogram(sch.linkage(df1,method='ward'))
plt.title('dendogram')
plt.xlabel('country')
plt.ylabel('Euclidean distance')
plt.show()

# %%
from sklearn.cluster import AgglomerativeClustering
hc=AgglomerativeClustering(n_clusters=3,affinity='euclidean',linkage='ward')
y_hc=hc.fit_predict(x_pca)

# %%
y_hc
# Out:
# array([0, 2, 2, 0, 2, 2, 2, 1, 1, 2, 2, 2, 2, 2, 2, 1, 2, 0, 2, 0, 2, 0,
#        2, 1, 2, 0, 0, 0, 0, 1, 2, 0, 0, 2, 2, 2, 0, 0, 0, 2, 0, 2, 1, 2,
#        1, 2, 2, 2, 2, 0, 0, 2, 0, 1, 1, 0, 0, 2, 1, 0, 1, 2, 0, 0, 0, 0,
#        0, 2, 1, 2, 2, 2, 0, 1, 2, 1, 2, 1, 0, 2, 0, 0, 1, 0, 0, 2, 2, 0,
#        0, 2, 2, 1, 2, 0, 0, 2, 2, 0, 1, 0, 2, 0, 2, 0, 2, 2, 0, 2, 0, 2,
#        1, 1, 0, 0, 1, 2, 0, 2, 2, 2, 0, 2, 1, 1, 2, 2, 0, 0, 2, 0, 2, 2,
#        0, 1, 2, 1, 0, 0, 1, 1, 2, 2, 0, 2, 1, 1, 0, 0, 2, 0, 0, 0, 2, 2,
#        0, 0, 2, 1, 1, 1, 2, 2, 0, 2, 2, 0, 0], dtype=int64)

# %%
df['cluster_labels']=y_hc

# %%
df.cluster_labels.value_counts()
# Out:
# 2    72
# 0    63
# 1    32
# Name: cluster_labels, dtype: int64

# %%
df[df['cluster_labels'] == 0].head()
# Out:
#         country  child_mort  exports  health  imports   income  inflation  \
# 0   Afghanistan        90.2     10.0    7.58     44.9   1610.0      9.440
# 3        Angola       119.0     62.3    2.85     42.9   5900.0     22.400
# 17        Benin       111.0     23.8    4.10     37.2   1820.0      0.885
# 19      Bolivia        46.6     41.2    4.84     34.3   5410.0      8.780
# 21     Botswana        52.5     43.6    8.30     51.3  13300.0      8.920
#
#     life_expec  total_fer    gdpp  cluster_labels
# 0         56.2       5.82   553.0               0
# 3         60.1       6.16  3530.0               0
# 17        61.8       5.36   758.0               0
# 19        71.6       3.20  1980.0               0
# 21        57.1       2.88  6350.0               0

# %%
df1=df[df['cluster_labels'] == 0].sort_values(by = ['child_mort','income', 'gdpp'], ascending = [False,True, True])
df1.head(10)
# Out:
#                       country  child_mort  exports  health  imports  income  \
# 66                      Haiti       208.0     15.3    6.91     64.7  1500.0
# 132              Sierra Leone       160.0     16.8   13.10     34.5  1220.0
# 32                       Chad       150.0     36.8    4.53     43.5  1930.0
# 31   Central African Republic       149.0     11.8    3.98     26.5   888.0
# 97                       Mali       137.0     22.8    4.98     35.1  1870.0
# 113                   Nigeria       130.0     25.3    5.07     17.4  5150.0
# 112                     Niger       123.0     22.2    5.16     49.1   814.0
# 3                      Angola       119.0     62.3    2.85     42.9  5900.0
# 37           Congo, Dem. Rep.       116.0     41.1    7.91     49.6   609.0
# 25               Burkina Faso       116.0     19.2    6.74     29.6  1430.0
#
#      inflation  life_expec  total_fer    gdpp  cluster_labels
# 66    5.450000        32.1   3.330000   662.0               0
# 132  17.200000        55.0   5.200000   399.0               0
# 32    6.390000        56.5   6.551572   897.0               0
# 31    2.010000        47.5   5.210000   446.0               0
# 97    4.370000        59.5   6.550000   708.0               0
# 113  39.463337        60.5   5.840000  2330.0               0
# 112   2.550000        58.8   6.551572   348.0               0
# 3    22.400000        60.1   6.160000  3530.0               0
# 37   20.800000        57.5   6.540000   334.0               0
# 25    6.810000        57.9   5.870000   575.0               0

# %%
sns.scatterplot(x='child_mort', y='income', hue='cluster_labels',data=df, palette='Set1')
plt.title('Clusters of Child mortality and income')
# Out:
# Text(0.5, 1.0, 'Clusters of Child mortality and income')

# %%
sns.scatterplot(x='health', y='income', hue='cluster_labels',data=df, palette='Set1')
plt.title('Clusters of Child mortality and income')
# Out:
# Text(0.5, 1.0, 'Clusters of Child mortality and income')

# %%
df1.head(5)
# Out:
#                       country  child_mort  exports  health  imports  income  \
# 66                      Haiti       208.0     15.3    6.91     64.7  1500.0
# 132              Sierra Leone       160.0     16.8   13.10     34.5  1220.0
# 32                       Chad       150.0     36.8    4.53     43.5  1930.0
# 31   Central African Republic       149.0     11.8    3.98     26.5   888.0
# 97                       Mali       137.0     22.8    4.98     35.1  1870.0
#
#      inflation  life_expec  total_fer   gdpp  cluster_labels
# 66        5.45        32.1   3.330000  662.0               0
# 132      17.20        55.0   5.200000  399.0               0
# 32        6.39        56.5   6.551572  897.0               0
# 31        2.01        47.5   5.210000  446.0               0
# 97        4.37        59.5   6.550000  708.0               0
